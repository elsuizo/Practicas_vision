# %% [markdown]
# ##Ejercicio 4
#
# ###Mostrar el efecto de descomponer una imagen color con el formato bmp en sus tres canales (R,G,B)  y compararla con la original (Se entregarán imágenes de prueba para realizar este punto)

# %%
#Imports 
import Images
import PyPlot
# Out:
# INFO: Loading help data...

# %%
#Imagen de prueba
path1 = "../Imagenes/Lapices.bmp";

# %%
img = Images.imread(path1);

# %%
PyPlot.imshow(convert(Array, img))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb43126090>)
# PyObject <matplotlib.image.AxesImage object at 0x7fcb5a3a06d0>

# %% [markdown]
# ###El Package de Julia Image.jl posee una función para extraer los canales directamente, tambien se puede acceder a los canales directamente (ejemplo: img_red = img_arr[:,:,1] .. and so on)

# %%
img_red = Images.red(img);

# %%
#Transpose for the conversion(bug?¿)
PyPlot.imshow(img_red',cmap="gray")
PyPlot.title("Canal Rojo")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb5a312c50>)
# PyObject <matplotlib.text.Text object at 0x7fcb3f2eee10>

# %%
img_green = Images.green(img);

# %%
#Transpose for the conversion(bug?¿)
PyPlot.imshow(img_green',cmap="gray")
PyPlot.title("Canal Verde")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb5a213910>)
# PyObject <matplotlib.text.Text object at 0x7fcb3f2a0310>

# %%
img_blue = Images.blue(img);

# %%
#Transpose for the conversion(bug?¿)
PyPlot.imshow(img_blue',cmap="gray")
PyPlot.title("Canal Azul")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb3f3634d0>)
# PyObject <matplotlib.text.Text object at 0x7fcb3f1c97d0>
