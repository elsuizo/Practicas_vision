# %% [markdown]
# ##Ejercicio 1
# Adquirir 3 imágenes en tonalidades de gris de 2 objetos distintos con iluminación de intensidad baja, media y alta (total: 6 imágenes).

# %%
using Images

# %%
using VideoIO

# %%
import PyPlot
# Out:
# PyPlot not found
# while loading In[3], in expression starting on line 1
#  in require at loading.jl:47

# %%
path1 = "../Imagenes/sci-2.bmp"
path2 = "../Imagenes/sci-3.bmp"
path3 = "../Imagenes/sci-4.bmp"
path4 = "../Imagenes/tar-5.bmp"
path5 = "../Imagenes/tar-6.bmp"
path6 = "../Imagenes/tar-7.bmp"
# Out:
# "../Imagenes/tar-7.bmp"

# %%
img1 = imread(path1);
img1 = imread(path1);
img2 = imread(path2);
img3 = imread(path3);
img4 = imread(path4);
img5 = imread(path5);
img6 = imread(path6);

# %%
PyPlot.figure()
PyPlot.imshow(convert(Array,img1))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fc50df85c90>)
# PyObject <matplotlib.image.AxesImage object at 0x7fc50de31490>

# %%
fig, axarr = PyPlot.subplots(2,3)
#fig.set_size_inches(10,10)
PyPlot.imshow(axarr[1,1])
# Out:
# PyError (PyObject_Call) <type 'exceptions.TypeError'>
# TypeError('Image data can not convert to float',)
#   File "/home/elsuizo/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py", line 2892, in imshow
#     imlim=imlim, resample=resample, url=url, **kwargs)
#   File "/home/elsuizo/anaconda/lib/python2.7/site-packages/matplotlib/axes.py", line 7300, in imshow
#     im.set_data(X)
#   File "/home/elsuizo/anaconda/lib/python2.7/site-packages/matplotlib/image.py", line 425, in set_data
#     raise TypeError("Image data can not convert to float")
#
# while loading In[21], in expression starting on line 3
#  in getindex at /home/elsuizo/.julia/v0.3/PyCall/src/PyCall.jl:625
#  in pysequence_query at /home/elsuizo/.julia/v0.3/PyCall/src/conversions.jl:741
#  in pytype_query at /home/elsuizo/.julia/v0.3/PyCall/src/conversions.jl:757
#  in convert at /home/elsuizo/.julia/v0.3/PyCall/src/conversions.jl:806
#  in pycall at /home/elsuizo/.julia/v0.3/PyCall/src/PyCall.jl:795
#  in fn at /home/elsuizo/.julia/v0.3/PyCall/src/conversions.jl:181
#  in anonymous at /home/elsuizo/.julia/v0.3/PyPlot/src/PyPlot.jl:206
